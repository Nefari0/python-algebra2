# %%
# log and linearly spaced numbers
import numpy as np
import matplotlib.pyplot as plt

# %%
np.linspace(1,2,10)
# Out:
# array([1.        , 1.11111111, 1.22222222, 1.33333333, 1.44444444,
#        1.55555556, 1.66666667, 1.77777778, 1.88888889, 2.        ])

# %%
# np.logspace(1,2,10) # (power of,power of,base)

a = np.log10(1)
b = np.log10(2)

np.logspace(a,b,10)
# Out:
# array([1.        , 1.08005974, 1.16652904, 1.25992105, 1.36079   ,
#        1.46973449, 1.58740105, 1.71448797, 1.85174942, 2.        ])

# %%
# exercise.independent

a = np.log10(1)
b = np.log10(100)
x1 = np.linspace(1,100,100)
x2 = np.logspace(a,b,100)
y = list(range(len(x1)))

print(len(x2),len(x1),len(y))

plt.plot(x2,y)
plt.plot(x1,y)
plt.axis('square')
# Out:
# 100 100 100
# (-3.95, 104.95, -4.95, 103.95)

# %%
# exercise.instructed
a = 2
b = 100
n = 50

li = np.linspace(a,b,n)
lo = np.logspace(np.log10(a),np.log10(b),n)

plt.plot(li,li,label='linear')
plt.plot(li,lo,label='log')

plt.legend()
plt.axis('square')
# Out:
# (-2.9000000000000004, 104.9, -2.9000000000000004, 104.9)

# %%
# experimental
dems = 50
a = np.log10(1)
b = np.log10(100)
x1 = np.linspace(1,100,dems)
x2 = np.logspace(a,b,dems)
y = list(range(dems))

print(len(x2),len(x1),len(y))

plt.plot(x2,y)
plt.plot(x1,y)
plt.axis('square')
# Out:
# 50 50 50
# (-3.95, 104.95, -2.45, 106.45)
