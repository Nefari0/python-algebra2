# %%
import numpy as np
import random as random
import sympy as sym
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot

# %%
# discreet derivative yt = xt + 1 - xt

# %%
x = [1,5,4]

# %%
np.diff(x) # compute difference between current point and next point
# Out:
# array([ 4, -1])

# %%
v = np.arange(1,11)
print(len(v))
print(len(np.diff(v,prepend=2)))
print(len(np.diff(v,2)))
# Out:
# 10
# 10
# 8

# %%
# x = sym.symbols('x')
x = np.linspace(-2,2,50)
# x = np.arange(-2,3)
y = np.zeros(len(x))
yt = list(range(len(x)))

# print(yt)
for yi in range(0,len(x)):
    y[yi] = x[yi]**2
    yt[yi] = x[yi]**2
#     plt.plot(x,y)



plt.plot(x,y)
# plt.plot(x,y)
plt.show()
print(len(yt),len(x),len(y))
print(np.diff(yt))
# Out:
# 50 50 50
# [-0.31986672 -0.30653894 -0.29321116 -0.27988338 -0.2665556  -0.25322782
#  -0.23990004 -0.22657226 -0.21324448 -0.1999167  -0.18658892 -0.17326114
#  -0.15993336 -0.14660558 -0.1332778  -0.11995002 -0.10662224 -0.09329446
#  -0.07996668 -0.0666389  -0.05331112 -0.03998334 -0.02665556 -0.01332778
#   0.          0.01332778  0.02665556  0.03998334  0.05331112  0.0666389
#   0.07996668  0.09329446  0.10662224  0.11995002  0.1332778   0.14660558
#   0.15993336  0.17326114  0.18658892  0.1999167   0.21324448  0.22657226
#   0.23990004  0.25322782  0.2665556   0.27988338  0.29321116  0.30653894
#   0.31986672]

# %%
# exercise main. independent
# x = sym.symbols('x')
x = np.linspace(-2,2,50)
# x = np.arange(-2,3)
y = np.zeros(len(x))
yt = list(range(len(x)))

# print(yt)
for yi in range(0,len(x)):
    y[yi] = x[yi]**2
    yt[yi] = x[yi]**2
#     plt.plot(x,y)

diriv = np.diff(yt)
# diriv = +1

plt.plot(x,y)
# plt.plot(x,diriv)
plt.show()
print(len(diriv),len(x),len(y))
print(diriv)

# plot diriv
for i in range(len(diriv)):
    yt[i] = diriv[i]
#     print(yt[i])
print(yt[1:-1])
plt.plot(x,yt)
# Out:
# 49 50 50
# [-0.31986672 -0.30653894 -0.29321116 -0.27988338 -0.2665556  -0.25322782
#  -0.23990004 -0.22657226 -0.21324448 -0.1999167  -0.18658892 -0.17326114
#  -0.15993336 -0.14660558 -0.1332778  -0.11995002 -0.10662224 -0.09329446
#  -0.07996668 -0.0666389  -0.05331112 -0.03998334 -0.02665556 -0.01332778
#   0.          0.01332778  0.02665556  0.03998334  0.05331112  0.0666389
#   0.07996668  0.09329446  0.10662224  0.11995002  0.1332778   0.14660558
#   0.15993336  0.17326114  0.18658892  0.1999167   0.21324448  0.22657226
#   0.23990004  0.25322782  0.2665556   0.27988338  0.29321116  0.30653894
#   0.31986672]
# ...

# %%
# experimental
# x = sym.symbols('x')
x = np.linspace(-2,2,50)
# x = np.arange(-2,3)
y = np.zeros(len(x))
yt = list(range(len(x)))
# diriv = list(range(len(x)))

# print(yt)
for yi in range(0,len(x)):
    y[yi] = x[yi]**2
#     yt[yi] = x[yi]**2
#     plt.plot(x,y)

diriv = np.diff(y,prepend=+10)
print(len(diriv))
print(diriv)


plt.plot(x,y)
plt.plot(x,diriv)
# plt.show()
# print(len(diriv),len(x),len(y))
# print(diriv)

# # plot diriv
# for i in range(len(diriv)):
#     yt[i] = diriv[i]
# #     print(yt[i])
# print(yt[1:-1])
# plt.plot(x,yt)
# Out:
# 50
# [-6.         -0.31986672 -0.30653894 -0.29321116 -0.27988338 -0.2665556
#  -0.25322782 -0.23990004 -0.22657226 -0.21324448 -0.1999167  -0.18658892
#  -0.17326114 -0.15993336 -0.14660558 -0.1332778  -0.11995002 -0.10662224
#  -0.09329446 -0.07996668 -0.0666389  -0.05331112 -0.03998334 -0.02665556
#  -0.01332778  0.          0.01332778  0.02665556  0.03998334  0.05331112
#   0.0666389   0.07996668  0.09329446  0.10662224  0.11995002  0.1332778
#   0.14660558  0.15993336  0.17326114  0.18658892  0.1999167   0.21324448
#   0.22657226  0.23990004  0.25322782  0.2665556   0.27988338  0.29321116
#   0.30653894  0.31986672]

# %%
# experimental
# x = sym.symbols('x')
x = np.linspace(-2,2,50)
# x = np.arange(-2,3)
y = np.zeros(len(x))
yt = list(range(len(x)))
diriv = list(range(len(x)))

print(len(diriv))
for yi in range(len(x)):
    y[yi] = x[yi]**2
#     print(x[yi])

diriv = np.diff(y,prepend=1)
print(len(diriv))
print(diriv)


plt.plot(x,y)
plt.plot(x,diriv)
# plt.show()
# print(len(diriv),len(x),len(y))
# print(diriv)

# # plot diriv
# for i in range(len(diriv)):
#     yt[i] = diriv[i]
# #     print(yt[i])
# print(yt[1:-1])
# plt.plot(x,yt)
# Out:
# 50
# 50
# [ 3.         -0.31986672 -0.30653894 -0.29321116 -0.27988338 -0.2665556
#  -0.25322782 -0.23990004 -0.22657226 -0.21324448 -0.1999167  -0.18658892
#  -0.17326114 -0.15993336 -0.14660558 -0.1332778  -0.11995002 -0.10662224
#  -0.09329446 -0.07996668 -0.0666389  -0.05331112 -0.03998334 -0.02665556
#  -0.01332778  0.          0.01332778  0.02665556  0.03998334  0.05331112
#   0.0666389   0.07996668  0.09329446  0.10662224  0.11995002  0.1332778
#   0.14660558  0.15993336  0.17326114  0.18658892  0.1999167   0.21324448
#   0.22657226  0.23990004  0.25322782  0.2665556   0.27988338  0.29321116
#   0.30653894  0.31986672]

# %%
# exercise.instructed
x = np.linspace(-2,2,101)
f = x**2
df = np.diff(f)

plt.plot(x,f,label='f')
plt.plot(x[0:-1],df,label='df')

plt.grid()
plt.axis([-2,2,-1,2])
plt.legend()
plt.show()
